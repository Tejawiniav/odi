# %%
import pandas as pd
import numpy as np

# %%
x=pd.read_csv(r'D:\Tejaswini\odi-batting.csv')
x.head()
# Out:
#        Country            Player   Runs  ScoreRate  MatchDate  \
# 0  Afghanistan  Mohammad Shahzad  118.0      97.52  2-16-2010
# 1  Afghanistan  Mohammad Shahzad  110.0      99.09   9-1-2009
# 2  Afghanistan  Mohammad Shahzad  100.0     138.88  8-16-2010
# 3  Afghanistan  Mohammad Shahzad   82.0      75.92  7-10-2010
# 4  Afghanistan  Mohammad Shahzad   57.0     100.00   7-1-2010
#
#                   Ground       Versus  \
# 0     Sharjah CA Stadium       Canada
# 1             VRA Ground  Netherlands
# 2  Cambusdoon New Ground     Scotland
# 3            Hazelaarweg  Netherlands
# 4    Sportpark Westvliet       Canada
#
#                                                 URL
# 0  ../Matches/MatchScorecard_ODI.asp?MatchCode=3087
# 1  ../Matches/MatchScorecard_ODI.asp?MatchCode=3008
# 2  ../Matches/MatchScorecard_ODI.asp?MatchCode=3164
# 3  ../Matches/MatchScorecard_ODI.asp?MatchCode=3153
# 4  ../Matches/MatchScorecard_ODI.asp?MatchCode=3135

# %%
x.shape
# Out:
# (55926, 8)

# %%
x.size
# Out:
# 447408

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55926 entries, 0 to 55925
# Data columns (total 8 columns):
# Country      55926 non-null object
# Player       55926 non-null object
# Runs         55900 non-null float64
# ScoreRate    55900 non-null float64
# MatchDate    55926 non-null object
# Ground       55926 non-null object
# Versus       55926 non-null object
# URL          55926 non-null object
# dtypes: float64(2), object(6)
# memory usage: 2.1+ MB

# %%
x.columns
# Out:
# Index(['Country', 'Player', 'Runs', 'ScoreRate', 'MatchDate', 'Ground',
#        'Versus', 'URL'],
#       dtype='object')

# %%
x.index
# Out:
# RangeIndex(start=0, stop=55926, step=1)

# %%
x.index.name='Index'

# %%
x.head()
# Out:
#            Country            Player   Runs  ScoreRate  MatchDate  \
# Index
# 0      Afghanistan  Mohammad Shahzad  118.0      97.52  2-16-2010
# 1      Afghanistan  Mohammad Shahzad  110.0      99.09   9-1-2009
# 2      Afghanistan  Mohammad Shahzad  100.0     138.88  8-16-2010
# 3      Afghanistan  Mohammad Shahzad   82.0      75.92  7-10-2010
# 4      Afghanistan  Mohammad Shahzad   57.0     100.00   7-1-2010
#
#                       Ground       Versus  \
# Index
# 0         Sharjah CA Stadium       Canada
# 1                 VRA Ground  Netherlands
# 2      Cambusdoon New Ground     Scotland
# 3                Hazelaarweg  Netherlands
# 4        Sportpark Westvliet       Canada
#
#                                                     URL
# Index
# 0      ../Matches/MatchScorecard_ODI.asp?MatchCode=3087
# 1      ../Matches/MatchScorecard_ODI.asp?MatchCode=3008
# 2      ../Matches/MatchScorecard_ODI.asp?MatchCode=3164
# 3      ../Matches/MatchScorecard_ODI.asp?MatchCode=3153
# ...

# %%
x.dtypes
# Out:
# Country       object
# Player        object
# Runs         float64
# ScoreRate    float64
# MatchDate     object
# Ground        object
# Versus        object
# URL           object
# dtype: object

# %%
x.describe()
# Out:
#                Runs     ScoreRate
# count  55900.000000  55900.000000
# mean      22.241413     65.314208
# std       25.558363     44.213423
# min        0.000000      0.000000
# 25%        4.000000     37.500000
# 50%       13.000000     62.660000
# 75%       32.000000     87.500000
# max      200.000000    600.000000

# %%
x.iloc[0:5,0:1 ]
# Out:
#            Country
# Index
# 0      Afghanistan
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan

# %%
x.iloc[0:5,1 ]
# Out:
# Index
# 0    Mohammad Shahzad
# 1    Mohammad Shahzad
# 2    Mohammad Shahzad
# 3    Mohammad Shahzad
# 4    Mohammad Shahzad
# Name: Player, dtype: object

# %%
x.iloc[0:5,3 ]
# Out:
# Index
# 0     97.52
# 1     99.09
# 2    138.88
# 3     75.92
# 4    100.00
# Name: ScoreRate, dtype: float64

# %%
x.iloc[0:5,4]
# Out:
# Index
# 0    2-16-2010
# 1     9-1-2009
# 2    8-16-2010
# 3    7-10-2010
# 4     7-1-2010
# Name: MatchDate, dtype: object

# %%
x.iloc[0:5,5 ]
# Out:
# Index
# 0       Sharjah CA Stadium
# 1               VRA Ground
# 2    Cambusdoon New Ground
# 3              Hazelaarweg
# 4      Sportpark Westvliet
# Name: Ground, dtype: object

# %%
x.iloc[0:5,6 ]
# Out:
# Index
# 0         Canada
# 1    Netherlands
# 2       Scotland
# 3    Netherlands
# 4         Canada
# Name: Versus, dtype: object

# %%
x.iloc[0:5,7 ]
# Out:
# Index
# 0    ../Matches/MatchScorecard_ODI.asp?MatchCode=3087
# 1    ../Matches/MatchScorecard_ODI.asp?MatchCode=3008
# 2    ../Matches/MatchScorecard_ODI.asp?MatchCode=3164
# 3    ../Matches/MatchScorecard_ODI.asp?MatchCode=3153
# 4    ../Matches/MatchScorecard_ODI.asp?MatchCode=3135
# Name: URL, dtype: object

# %%
x.iloc[0:5,0:4]
# Out:
#            Country            Player   Runs  ScoreRate
# Index
# 0      Afghanistan  Mohammad Shahzad  118.0      97.52
# 1      Afghanistan  Mohammad Shahzad  110.0      99.09
# 2      Afghanistan  Mohammad Shahzad  100.0     138.88
# 3      Afghanistan  Mohammad Shahzad   82.0      75.92
# 4      Afghanistan  Mohammad Shahzad   57.0     100.00

# %%
x['Country'].unique()
# Out:
# array(['Afghanistan', 'Australia', 'Bangladesh', 'Bermuda', 'Canada',
#        'East Africa', 'England', 'Hong Kong', 'India', 'Ireland', 'Kenya',
#        'Namibia', 'Netherlands', 'New Zealand', 'Pakistan', 'Scotland',
#        'South Africa', 'Sri Lanka', 'United Arab Emirates',
#        'United States', 'West Indies', 'Zimbabwe'], dtype=object)

# %%
x['Player'].unique()
# Out:
# array(['Mohammad Shahzad', 'Mohammad Nabi', 'Nawroz Mangal', ...,
#        'Waddington Mwayenga', 'Tafadzwa Kamungozi', 'Njabulo Ncube'],
#       dtype=object)

# %%
x['Country'].value_counts()
# Out:
# India                   6634
# Pakistan                6603
# Australia               6325
# Sri Lanka               5604
# West Indies             5557
# New Zealand             5437
# England                 5101
# South Africa            3864
# Zimbabwe                3814
# Bangladesh              2459
# Kenya                   1379
# Canada                   685
# Ireland                  624
# Netherlands              604
# Scotland                 459
# Bermuda                  343
# Afghanistan              161
# United Arab Emirates     114
# Namibia                   62
# Hong Kong                 44
# East Africa               32
# United States             21
# Name: Country, dtype: int64

# %%
x['Player'].value_counts()
# Out:
# Sachin R Tendulkar        442
# Sanath T Jayasuriya       433
# Ricky T Ponting           360
# Inzamam-ul-Haq            351
# D P Mahela Jayawardene    330
# Rahul Dravid              318
# Mohammad Azharuddin       308
# Jacques H Kallis          303
# Shahid Afridi             303
# Sourav C Ganguly          300
# Pinnaduwage A de Silva    296
# Brian C Lara              289
# Stephen R Waugh           288
# Kumar C Sangakkara        282
# Wasim Akram               280
# Adam C Gilchrist          279
# Mohammad Yousuf           273
# Stephen P Fleming         269
# Marvan S Atapattu         259
# Salim Malik               256
# Arjuna Ranatunga          255
# Yuvraj Singh              252
# Allan R Border            252
# Shivnarine Chanderpaul    251
# Saeed Anwar               244
# Herschelle H Gibbs        240
# Desmond L Haynes          237
# Mark E Waugh              237
# Ijaz Ahmed                232
# Virender Sehwag           230
#                          ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(30,8))

sns.countplot(x='Country',data=x)

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='Player',data=x)

# %%
x_country=x['Country'].value_counts()[:10]
x_country
# Out:
# India           6634
# Pakistan        6603
# Australia       6325
# Sri Lanka       5604
# West Indies     5557
# New Zealand     5437
# England         5101
# South Africa    3864
# Zimbabwe        3814
# Bangladesh      2459
# Name: Country, dtype: int64

# %%
x['Country'].value_counts()[:10].plot(kind='barh')

# %%
x['Player'].value_counts()[:10]
# Out:
# Sachin R Tendulkar        442
# Sanath T Jayasuriya       433
# Ricky T Ponting           360
# Inzamam-ul-Haq            351
# D P Mahela Jayawardene    330
# Rahul Dravid              318
# Mohammad Azharuddin       308
# Jacques H Kallis          303
# Shahid Afridi             303
# Sourav C Ganguly          300
# Name: Player, dtype: int64

# %%
x['Player'].value_counts()[:10].plot(kind='barh')

# %%
x_india=x[x.Country=='India']
x_india
# Out:
#       Country                       Player   Runs  ScoreRate   MatchDate  \
# Index
# 15150   India           Sachin R Tendulkar  200.0     136.05   2-24-2010
# 15151   India           Sachin R Tendulkar  186.0     124.00   11-8-1999
# 15152   India           Sachin R Tendulkar  175.0     124.11   11-5-2009
# 15153   India           Sachin R Tendulkar  163.0     122.55    3-8-2009
# 15154   India           Sachin R Tendulkar  152.0     100.66   2-23-2003
# 15155   India           Sachin R Tendulkar  146.0      95.42   12-8-2000
# 15156   India           Sachin R Tendulkar  146.0     110.60  10-24-2001
# 15157   India           Sachin R Tendulkar  143.0     109.16   4-22-1998
# 15158   India           Sachin R Tendulkar  141.0     104.44   3-16-2004
# 15159   India           Sachin R Tendulkar  141.0      95.27   9-14-2006
# 15160   India           Sachin R Tendulkar  141.0     110.15  10-28-1998
# 15161   India           Sachin R Tendulkar  140.0     138.61   5-23-1999
# ...

# %%
y=x[(x.Runs==0.0)&(x.ScoreRate==00.0)]
y['Player'].value_counts()[:10]
# Out:
# Muttiah Muralitharan      41
# Sanath T Jayasuriya       34
# Wasim Akram               32
# Glenn D McGrath           32
# W P U J Chaminda Vaas     30
# D P Mahela Jayawardene    26
# Daniel L Vettori          26
# Shahid Afridi             26
# Javagal Srinath           25
# Romesh S Kaluwitharana    24
# Name: Player, dtype: int64

# %%
x[(x.Player=='Sachin R Tendulkar')&(x.Runs==0.0)]
# Out:
#       Country              Player  Runs  ScoreRate   MatchDate  \
# Index
# 15572   India  Sachin R Tendulkar   0.0        0.0  11-17-1999
# 15573   India  Sachin R Tendulkar   0.0        0.0   3-19-2004
# 15574   India  Sachin R Tendulkar   0.0        0.0   1-24-2007
# 15575   India  Sachin R Tendulkar   0.0        0.0    7-7-2001
# 15576   India  Sachin R Tendulkar   0.0        0.0    1-9-1999
# 15577   India  Sachin R Tendulkar   0.0        0.0   3-23-2007
# 15578   India  Sachin R Tendulkar   0.0        0.0    9-8-1999
# 15579   India  Sachin R Tendulkar   0.0        0.0   2-19-2008
# 15580   India  Sachin R Tendulkar   0.0        0.0    6-4-1999
# 15581   India  Sachin R Tendulkar   0.0        0.0   2-16-2006
# 15582   India  Sachin R Tendulkar   0.0        0.0   9-29-2007
# 15583   India  Sachin R Tendulkar   0.0        0.0   9-18-1997
# 15584   India  Sachin R Tendulkar   0.0        0.0    1-8-2003
# 15585   India  Sachin R Tendulkar   0.0        0.0  10-25-1991
# ...

# %%
y=x[(x.Country=='India')&(x.Versus=='Zimbabwe')&(x.ScoreRate>=100)]
y
# Out:
#       Country                   Player   Runs  ScoreRate   MatchDate  \
# Index
# 15169   India       Sachin R Tendulkar  124.0     134.78  11-13-1998
# 15175   India       Sachin R Tendulkar  118.0     105.35   11-8-1998
# 15188   India       Sachin R Tendulkar  104.0     107.21    2-9-1997
# 15223   India       Sachin R Tendulkar   85.0     118.05    9-4-1999
# 15232   India       Sachin R Tendulkar   81.0     105.19    3-7-1992
# 15242   India       Sachin R Tendulkar   70.0     100.00   6-24-2001
# 15370   India       Sachin R Tendulkar   29.0     138.09   9-27-1998
# 15393   India       Sachin R Tendulkar   24.0     150.00  11-18-1993
# 15477   India       Sachin R Tendulkar    8.0     133.33   3-22-1993
# 15626   India         Sourav C Ganguly   86.0     103.61   3-10-2002
# 15648   India         Sourav C Ganguly   71.0     104.41  12-11-2000
# 15722   India         Sourav C Ganguly   32.0     123.07   1-14-2004
# ...

# %% [markdown]
# ## from datetime import datetime,date,time
